# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("unemploymentrate.csv")

# %%
print("shape (rows,columns): ",df.shape)
# Out:
# shape (rows,columns):  (2838, 14)

# %%
df.head()
# Out:
#          When           AgeGroup         Sex  Alberta  BritishColumbia  \
# 0  01/01/1976  15 years and over     Females      5.2              9.7
# 1  01/01/1976  15 years and over       Males      3.8              7.8
# 2  01/01/1976     15 to 24 years       Males      8.0             15.3
# 3  01/01/1976     15 to 24 years     Females      8.3             12.9
# 4  01/01/1976     15 to 24 years  Both sexes      8.1             14.2
#
#    Canada  Manitoba  NewBrunswick  NewfoundlandAndLabrador  NovaScotia  \
# 0     8.1       5.2          11.4                     11.5         8.3
# 1     6.4       5.8          11.1                     12.6         7.6
# 2    13.2      11.9          17.2                     19.2        14.5
# 3    11.2       9.6          15.1                     16.5        14.0
# 4    12.3      10.8          16.3                     18.1        14.3
#
#    Ontario  PrinceEdwardIsland  Quebec  Saskatchewan
# 0      8.1                10.8     8.9           4.3
# ...

# %%
df.head(13)
# Out:
#           When           AgeGroup         Sex  Alberta  BritishColumbia  \
# 0   01/01/1976  15 years and over     Females      5.2              9.7
# 1   01/01/1976  15 years and over       Males      3.8              7.8
# 2   01/01/1976     15 to 24 years       Males      8.0             15.3
# 3   01/01/1976     15 to 24 years     Females      8.3             12.9
# 4   01/01/1976     15 to 24 years  Both sexes      8.1             14.2
# 5   01/01/1976  15 years and over  Both sexes      4.3              8.5
# 6   02/01/1976  15 years and over  Both sexes      3.7              8.4
# 7   02/01/1976     15 to 24 years  Both sexes      6.8             13.7
# 8   02/01/1976     15 to 24 years     Females      6.9             12.3
# 9   02/01/1976     15 to 24 years       Males      6.8             14.9
# 10  02/01/1976  15 years and over       Males      3.4              7.6
# 11  02/01/1976  15 years and over     Females      4.3              9.6
# ...

# %%
display(df.columns)
# Out:
# Index(['When', 'AgeGroup', 'Sex', 'Alberta', 'BritishColumbia', 'Canada',
#        'Manitoba', 'NewBrunswick', 'NewfoundlandAndLabrador', 'NovaScotia',
#        'Ontario', 'PrinceEdwardIsland', 'Quebec', 'Saskatchewan'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2838 entries, 0 to 2837
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   When                     2838 non-null   object
#  1   AgeGroup                 2838 non-null   object
#  2   Sex                      2838 non-null   object
#  3   Alberta                  2838 non-null   float64
#  4   BritishColumbia          2838 non-null   float64
#  5   Canada                   2838 non-null   float64
#  6   Manitoba                 2838 non-null   float64
#  7   NewBrunswick             2838 non-null   float64
#  8   NewfoundlandAndLabrador  2838 non-null   float64
#  9   NovaScotia               2838 non-null   float64
#  10  Ontario                  2838 non-null   float64
#  11  PrinceEdwardIsland       2838 non-null   float64
#  12  Quebec                   2838 non-null   float64
# ...
